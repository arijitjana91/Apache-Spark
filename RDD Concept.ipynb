# %%
sc

# %%
a = [10,20,30,45,55,54,66,78,99]

# %%
type(a)

# %%
a

# %%
a[4]

# %%
rdd1= sc.parallelize(a)

# %%
rdd1

# %%
rdd1.collect()

# %%
rdd1.sum()
print(rdd1.sum())

# %%
rdd1.mean()

# %%
rdd1.count()

# %%
rdd1.max()

# %%
# emprdd=sc.textFile('/FileStore/tables/employees.txt')
emprdd=sc.textFile('/FileStore/tables/Arijit11Aug/emp_20.csv')

# %%
emprdd

# %%
emprdd.collect()

# %%
emprdd.count()

# %%
emprdd.first()

# %%
emprdd.take(5)

# %%
rdd1.getNumPartitions()

# %%
emprdd.getNumPartitions()

# %%
rdd1.glom().collect()

# %%
emprdd.glom().collect()

# %%
e1 = emprdd.map(lambda x: x.split(','))
e1.collect()

# %%
e2 = e1.map(lambda x: (x[5],x[4]))

# %%
e2.collect()

# %%
e3=e2.reduceByKey(lambda x,y: x+y)
e3.collect()

# %%
e4=e3.map(lambda x: (x[0],x[1]))
e4.collect()

# %%
e5=e4.sortByKey(True)
e5.collect()

# %%
dbutils.fs.ls("dbfs:/Volumes/demo/sample_schema/sample_volume/flights-1m.parquet")
